# %%
# %pip install EasyTTS
# %pip install git+https://github.com/repodiac/german_transliterate
# Out:
# Collecting EasyTTS
#   Using cached EasyTTS-0.3.2-py3-none-any.whl (6.6 kB)
# Collecting timm
#   Using cached timm-0.6.13-py3-none-any.whl (549 kB)
# Requirement already satisfied: numpy in /usr/local/python/3.10.4/lib/python3.10/site-packages (from EasyTTS) (1.22.4)
# Requirement already satisfied: soundfile in /usr/local/python/3.10.4/lib/python3.10/site-packages (from EasyTTS) (0.12.1)
# Requirement already satisfied: torch in /usr/local/python/3.10.4/lib/python3.10/site-packages (from EasyTTS) (2.0.0)
# Collecting TensorFlowTTS
#   Using cached TensorFlowTTS-1.8-py3-none-any.whl (128 kB)
# Requirement already satisfied: tensorflow in /usr/local/python/3.10.4/lib/python3.10/site-packages (from EasyTTS) (2.12.0)
# Requirement already satisfied: cffi>=1.0 in /home/codespace/.local/lib/python3.10/site-packages (from soundfile->EasyTTS) (1.15.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (2.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (16.0.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (1.6.3)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (0.4.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow->EasyTTS) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (1.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (2.12.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (1.51.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow->EasyTTS) (4.5.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow->EasyTTS) (23.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (2.12.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (1.14.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (2.12.0)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow->EasyTTS) (67.6.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow->EasyTTS) (23.3.3)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.22.3-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 7.1 MB/s eta 0:00:0000:01
# Collecting pyworld>=0.2.10
#   Using cached pyworld-0.3.2.tar.gz (214 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: inflect>=4.1.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from TensorFlowTTS->EasyTTS) (5.6.0)
# Collecting textgrid
#   Using cached TextGrid-1.5-py3-none-any.whl (10.0 kB)
# Collecting unidecode>=1.1.1
#   Using cached Unidecode-1.3.6-py3-none-any.whl (235 kB)
# Requirement already satisfied: pypinyin in /usr/local/python/3.10.4/lib/python3.10/site-packages (from TensorFlowTTS->EasyTTS) (0.48.0)
# Collecting g2pM
#   Using cached g2pM-0.1.2.5-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: PyYAML>=3.12 in /home/codespace/.local/lib/python3.10/site-packages (from TensorFlowTTS->EasyTTS) (6.0)
# Requirement already satisfied: click in /usr/local/python/3.10.4/lib/python3.10/site-packages (from TensorFlowTTS->EasyTTS) (8.1.3)
# Requirement already satisfied: librosa>=0.7.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from TensorFlowTTS->EasyTTS) (0.8.0)
# Requirement already satisfied: g2p-en in /usr/local/python/3.10.4/lib/python3.10/site-packages (from TensorFlowTTS->EasyTTS) (2.1.0)
# Requirement already satisfied: jamo>=0.4.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from TensorFlowTTS->EasyTTS) (0.4.1)
# Collecting huggingface-hub==0.0.8
#   Using cached huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Collecting dataclasses
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting TensorFlowTTS
#   Using cached TensorFlowTTS-1.6.1-py3-none-any.whl (126 kB)
# Collecting tensorflow-addons>=0.10.0
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 18.6 MB/s eta 0:00:00
# Collecting numba<=0.48
#   Using cached numba-0.48.0.tar.gz (2.0 MB)
#   Preparing metadata (setup.py) ... done
# Collecting TensorFlowTTS
#   Using cached TensorFlowTTS-1.6-py3-none-any.whl (126 kB)
#   Using cached TensorFlowTTS-1.1-py3-none-any.whl (121 kB)
#   Using cached TensorFlowTTS-0.11-py3-none-any.whl (118 kB)
# Collecting tensorflow-gpu>=2.3.1
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [39 lines of output]
#       Traceback (most recent call last):
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_vendor/packaging/requirements.py", line 35, in __init__
#           parsed = parse_requirement(requirement_string)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_vendor/packaging/_parser.py", line 64, in parse_requirement
#           return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_vendor/packaging/_parser.py", line 82, in _parse_requirement
#           url, specifier, marker = _parse_requirement_details(tokenizer)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_vendor/packaging/_parser.py", line 126, in _parse_requirement_details
#           marker = _parse_requirement_marker(
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_vendor/packaging/_parser.py", line 147, in _parse_requirement_marker
#           tokenizer.raise_syntax_error(
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_vendor/packaging/_tokenizer.py", line 163, in raise_syntax_error
#           raise ParserSyntaxError(
#       setuptools.extern.packaging._tokenizer.ParserSyntaxError: Expected end or semicolon (after name and no valid version specifier)
#           python_version>"3.7"
#                         ^
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-9063y6mz/tensorflow-gpu_a63eb42e74824f38bf804b41beb5d2a2/setup.py", line 40, in <module>
#           setuptools.setup()
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/__init__.py", line 107, in setup
#           _install_setup_requires(attrs)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/__init__.py", line 78, in _install_setup_requires
#           dist.parse_config_files(ignore_option_errors=True)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/dist.py", line 887, in parse_config_files
#           self._finalize_requires()
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/dist.py", line 594, in _finalize_requires
#           self._move_install_requirements_markers()
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/dist.py", line 634, in _move_install_requirements_markers
#           inst_reqs = list(_reqs.parse(spec_inst_reqs))
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_vendor/packaging/requirements.py", line 37, in __init__
#           raise InvalidRequirement(str(e)) from e
#       setuptools.extern.packaging.requirements.InvalidRequirement: Expected end or semicolon (after name and no valid version specifier)
#           python_version>"3.7"
#                         ^
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/repodiac/german_transliterate
#   Cloning https://github.com/repodiac/german_transliterate to /tmp/pip-req-build-r18w6ckr
#   Running command git clone --filter=blob:none --quiet https://github.com/repodiac/german_transliterate /tmp/pip-req-build-r18w6ckr
#   Resolved https://github.com/repodiac/german_transliterate to commit 4e01beba5f19adb9ccd72d0607a81f4ed7f6ee87
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: num2words in /usr/local/python/3.10.4/lib/python3.10/site-packages (from german-transliterate==0.1.3) (0.5.12)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from num2words->german-transliterate==0.1.3) (0.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import TTS

# %%
from TTS.api import TTS

# %%
model_name = TTS.list_models()[0]
# Init TTS
tts = TTS(model_name)
# Out:
#  > tts_models/multilingual/multi-dataset/your_tts is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400
#  > External Speaker Encoder Loaded !!
#  > initialization of language-embedding layers.
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400

# %%
tts.tts_to_file(text="Hello world!", speaker=tts.speakers[0], language=tts.languages[0], file_path="output.wav")
# Out:
#  > Text splitted to sentences.
# ['Hello world!']
#  > Processing time: 1.070058822631836
#  > Real-time factor: 0.6961996243538295

# %%
import soundfile as sf
from EasyTTS.inference.TTS import TTS

tts = TTS(lang="fr") # Instantiate the model for your language
audio = tts.predict(text="Bonjour à tous") # Make a prediction

sf.write('./audio_pip.wav', audio, 22050, "PCM_16") # Save output in .WAV file
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import soundfile as sf
# ----> 2 from EasyTTS.inference.TTS import TTS
#       4 tts = TTS(lang="fr") # Instantiate the model for your language
#       5 audio = tts.predict(text="Bonjour à tous") # Make a prediction
#
# ModuleNotFoundError: No module named 'EasyTTS'
